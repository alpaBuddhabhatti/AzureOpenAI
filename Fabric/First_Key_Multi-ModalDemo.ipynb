# %%
# !pip install azure-identity azure-keyvault-secrets
# !pip install --upgrade azure-identity
# !pip install python-dotenv
# Out:
# StatementMeta(, 18451b68-4067-4528-afd4-b1cccc5b42fd, 3, Finished, Available, Finished)
# Requirement already satisfied: azure-identity in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (1.15.0)
# Collecting azure-keyvault-secrets
#   Downloading azure_keyvault_secrets-4.9.0-py3-none-any.whl.metadata (29 kB)
# Collecting azure-core<2.0.0,>=1.23.0 (from azure-identity)
#   Downloading azure_core-1.32.0-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: cryptography>=2.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-identity) (42.0.2)
# Requirement already satisfied: msal<2.0.0,>=1.24.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-identity) (1.25.0)
# Requirement already satisfied: msal-extensions<2.0.0,>=0.3.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-identity) (1.0.0)
# Requirement already satisfied: isodate>=0.6.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-keyvault-secrets) (0.6.1)
# Requirement already satisfied: typing-extensions>=4.0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-keyvault-secrets) (4.9.0)
# Requirement already satisfied: requests>=2.21.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-core<2.0.0,>=1.23.0->azure-identity) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-core<2.0.0,>=1.23.0->azure-identity) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from cryptography>=2.5->azure-identity) (1.16.0)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from PyJWT[crypto]<3,>=1.0.0->msal<2.0.0,>=1.24.0->azure-identity) (2.4.0)
# Requirement already satisfied: portalocker<3,>=1.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from msal-extensions<2.0.0,>=0.3.0->azure-identity) (2.3.0)
# Requirement already satisfied: pycparser in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.23.0->azure-identity) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.23.0->azure-identity) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.23.0->azure-identity) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.23.0->azure-identity) (2024.2.2)
# Downloading azure_keyvault_secrets-4.9.0-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.0/87.0 kB 6.3 MB/s eta 0:00:00
# Downloading azure_core-1.32.0-py3-none-any.whl (198 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.9/198.9 kB 14.7 MB/s eta 0:00:00
# Installing collected packages: azure-core, azure-keyvault-secrets
#   Attempting uninstall: azure-core
#     Found existing installation: azure-core 2024.9.1
#     Uninstalling azure-core-2024.9.1:
#       Successfully uninstalled azure-core-2024.9.1
# Successfully installed azure-core-1.30.2 azure-keyvault-secrets-4.9.0
# Requirement already satisfied: azure-identity in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (1.15.0)
# Collecting azure-identity
#   Downloading azure_identity-1.19.0-py3-none-any.whl.metadata (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 kB 2.7 MB/s eta 0:00:00
# Collecting azure-core>=1.31.0 (from azure-identity)
#   Using cached azure_core-1.32.0-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: cryptography>=2.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-identity) (42.0.2)
# Collecting msal>=1.30.0 (from azure-identity)
#   Downloading msal-1.31.1-py3-none-any.whl.metadata (11 kB)
# Collecting msal-extensions>=1.2.0 (from azure-identity)
#   Downloading msal_extensions-1.2.0-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-identity) (4.9.0)
# Requirement already satisfied: requests>=2.21.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-core>=1.31.0->azure-identity) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-core>=1.31.0->azure-identity) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from cryptography>=2.5->azure-identity) (1.16.0)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity) (2.4.0)
# Requirement already satisfied: portalocker<3,>=1.4 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from msal-extensions>=1.2.0->azure-identity) (2.3.0)
# Requirement already satisfied: pycparser in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (2024.2.2)
# Downloading azure_identity-1.19.0-py3-none-any.whl (187 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.6/187.6 kB 21.6 MB/s eta 0:00:00
# Using cached azure_core-1.32.0-py3-none-any.whl (198 kB)
# Downloading msal-1.31.1-py3-none-any.whl (113 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.2/113.2 kB 36.1 MB/s eta 0:00:00
# Downloading msal_extensions-1.2.0-py3-none-any.whl (19 kB)
# Installing collected packages: azure-core, msal, msal-extensions, azure-identity
#   Attempting uninstall: azure-core
#     Found existing installation: azure-core 1.30.2
#     Uninstalling azure-core-1.30.2:
#       Successfully uninstalled azure-core-1.30.2
#   Attempting uninstall: msal
#     Found existing installation: msal 1.25.0
#     Uninstalling msal-1.25.0:
#       Successfully uninstalled msal-1.25.0
#   Attempting uninstall: msal-extensions
#     Found existing installation: msal-extensions 1.0.0
#     Uninstalling msal-extensions-1.0.0:
#       Successfully uninstalled msal-extensions-1.0.0
#   Attempting uninstall: azure-identity
#     Found existing installation: azure-identity 1.15.0
#     Uninstalling azure-identity-1.15.0:
#       Successfully uninstalled azure-identity-1.15.0
# Successfully installed azure-core-1.32.0 azure-identity-1.19.0 msal-1.31.1 msal-extensions-1.2.0
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.0.1

# %%
import os
for key, value in os.environ.items():
    print(f"{key}: {value}")
# Out:
# StatementMeta(, 18451b68-4067-4528-afd4-b1cccc5b42fd, 4, Finished, Available, Finished)
# PATH: /usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/snap/bin:/usr/local/cuda-11.5/bin:/home/trusted-service-user/cluster-env/trident_env/bin:/home/trusted-service-user/cluster-env/synapse_trident_r/bin:/usr/lib/miniforge3/bin
# HADOOP_CONF_DIR: /usr/hdp/5.4.20241017.1/hadoop/conf
# KQLMAGIC_EXTRAS_REQUIRE: sso
# SYNAPSE_ENABLE_CONFIG_MERGE_RULE: true
# LD_LIBRARY_PATH: /usr/hdp/current/hadoop-client/lib/native:/opt/gluten/dep:
# JVM_PID: 5722
# LOGNAME: trusted-service-user
# PWD: /mnt/var/hadoop/tmp/nm-local-dir/usercache/trusted-service-user/appcache/application_1737565578103_0001/container_1737565578103_0001_01_000001
# LOCAL_DIRS: /mnt/var/hadoop/tmp/nm-local-dir/usercache/trusted-service-user/appcache/application_1737565578103_0001
# PYTHONPATH: /opt/spark/python/lib/pyspark.zip:/opt/spark/python/lib/py4j-0.10.7-src.zip:/opt/spark/python/lib/pyspark.zip:/opt/spark/python/lib/py4j-0.10.7-src.zip:/mnt/var/hadoop/tmp/nm-local-dir/usercache/trusted-service-user/appcache/application_1737565578103_0001/container_1737565578103_0001_01_000001/pyspark.zip:/mnt/var/hadoop/tmp/nm-local-dir/usercache/trusted-service-user/appcache/application_1737565578103_0001/container_1737565578103_0001_01_000001/py4j-0.10.7-src.zip
# DOTNET_WORKER_2_1_0_DIR: /usr/local/bin/sparkdotnet/Microsoft.Spark.Worker/2.1.0-prerelease.22115.1
# REQUESTS_CA_BUNDLE: /etc/pki/ca-trust/extracted/openssl/ca-bundle.trust.crt
# LOG_DIRS: /var/log/yarn-nm/userlogs/application_1737565578103_0001/container_1737565578103_0001_01_000001
# HADOOP_YARN_HOME: /usr/hdp/5.4.20241017.1/hadoop-yarn
# LOCALIZATION_COUNTERS: 2388626,0,2,0,621
# NM_AUX_SERVICE_spark_shuffle:
# HADOOP_HOME: /usr/hdp/current/hadoop-yarn-nodemanager/../hadoop
# LOCAL_USER_DIRS: /mnt/var/hadoop/tmp/nm-local-dir/usercache/trusted-service-user/
# GIT_PYTHON_REFRESH: quiet
# SHLVL: 2
# SPARK_YARN_STAGING_DIR: abfss://19e7b7e8-2a22-4345-abbe-f9864fe28f03@spark5triproduks.dfs.core.windows.net/user/trusted-service-user/trusted-service-user/.sparkStaging/application_1737565578103_0001
# SPARKR_INLINE_SESSION_LEVEL_ENABLE: true
# SPARK_PREFER_IPV6: false
# JAVA_HOME: /usr/lib/jvm/msopenjdk-11
# LANG: en_US.UTF-8
# APP_SUBMIT_TIME_ENV: 1737565587690
# NM_HOST: vm-11062627
# PYSPARK_PYTHON: /home/trusted-service-user/cluster-env/trident_env/bin/python
# SPARK_HOME: .
# MMLSPARK_PLATFORM_INFO: synapse
# LIVY_SPARK_MAJOR_VERSION: 3
# PYTHONHASHSEED: 0
# _: /usr/lib/jvm/msopenjdk-11/bin/java
# APPLICATION_WEB_PROXY_BASE: /proxy/application_1737565578103_0001
# SSL_CERT_DIR: /etc/pki/ca-trust/extracted/openssl:/opt/olcclient
# NM_HTTP_PORT: 8042
# LIVY_SPARK_SESSION_SOURCE_ID: default
# PRELAUNCH_OUT: /var/log/yarn-nm/userlogs/application_1737565578103_0001/container_1737565578103_0001_01_000001/prelaunch.out
# NM_PORT: 14554
# PYSPARK_GATEWAY_SECRET: 5wqMvrCBNCfM3jNCf36qoKAXesr0uke7Plq3vEom4vw=
# USER: trusted-service-user
# CLASSPATH: /usr/lib/library-manager/bin/libraries/scala/*:/usr/lib/dw-connector/fabric/*:/mnt/var/hadoop/tmp/nm-local-dir/usercache/trusted-service-user/appcache/application_1737565578103_0001/container_1737565578103_0001_01_000001:/mnt/var/hadoop/tmp/nm-local-dir/usercache/trusted-service-user/appcache/application_1737565578103_0001/container_1737565578103_0001_01_000001/__spark_conf__:/mnt/var/hadoop/tmp/nm-local-dir/usercache/trusted-service-user/appcache/application_1737565578103_0001/container_1737565578103_0001_01_000001/__spark_libs__/*:/opt/spark/jars/*:/mnt/var/hadoop/tmp/nm-local-dir/usercache/trusted-service-user/appcache/application_1737565578103_0001/container_1737565578103_0001_01_000001/__spark_conf__/__hadoop_conf__
# PRELAUNCH_ERR: /var/log/yarn-nm/userlogs/application_1737565578103_0001/container_1737565578103_0001_01_000001/prelaunch.err
# PYSPARK_GATEWAY_PORT: 43227
# PYTHONUNBUFFERED: YES
# HADOOP_TOKEN_FILE_LOCATION: /mnt/var/hadoop/tmp/nm-local-dir/usercache/trusted-service-user/appcache/application_1737565578103_0001/container_1737565578103_0001_01_000001/container_tokens
# SPARK_USER: trusted-service-user
# DEBUG_PORT: 39539
# AZURE_SERVICE: Microsoft.ProjectArcadia
# HOME: /home/trusted-service-user
# CONTAINER_ID: container_1737565578103_0001_01_000001
# MALLOC_ARENA_MAX: 4
# PYDEVD_USE_FRAME_EVAL: NO
# JPY_PARENT_PID: 6715
# TERM: xterm-color
# CLICOLOR: 1
# FORCE_COLOR: 1
# CLICOLOR_FORCE: 1
# PAGER: cat
# GIT_PAGER: cat
# MPLBACKEND: module://matplotlib_inline.backend_inline
# SPARK_AUTH_SOCKET_TIMEOUT: 15
# SPARK_BUFFER_SIZE: 65536
# MLFLOW_TRACKING_URI: sds://
# AZURE_OPENAI_API_KEY: place_holder_for_fabric_internal
# OPENAI_API_KEY: place_holder_for_fabric_internal
# OPENAI_API_TYPE: azure

# %% [markdown]
# _**Example 1:**_ Image having two execution statements:
#
#            - --  EXEC DecodeDrivingLicenceNumber1 'Budd9051011Al90001'
#            - --  EXEC GenerateDrivingLicenceNumber 'Alpa', 'Budd', '2001-01-01', 'F';

# %%
import os
import requests
import base64
import json


# Configuration
GPT4V_KEY ="55457392c21046e8bf4223a6dac91316"
IMAGE_PATH = "/lakehouse/default/Files/Generat driving Licence.jpg"
encoded_image = base64.b64encode(open(IMAGE_PATH, 'rb').read()).decode('ascii')
headers = {
    "Content-Type": "application/json",
    "api-key": GPT4V_KEY,
}

# Payload for the request
payload = {
  "messages": [
    {
      "role": "system",
      "content": [
        {
          "type": "text",
          "text": "You are an AI assistant that helps people find information."
        }
      ]
    },
    {
      "role": "user",
      "content": [
        {
          "type": "image_url",
          "image_url": {
            "url": f"data:image/jpeg;base64,{encoded_image}"
          }
        },
        {
          "type": "text",
          "text": "can you please explin the image?"
        }
      ]
    }
  ],
  "temperature": 0.7,
  "top_p": 0.95,
  "max_tokens": 800
}

GPT4V_ENDPOINT = "https://yourazureoepnai.openai.azure.com/openai/deployments/gpt-40/chat/completions?api-version=2024-02-15-preview"

# Send request
try:
    response = requests.post(GPT4V_ENDPOINT, headers=headers, json=payload)
    response.raise_for_status()  # Will raise an HTTPError if the HTTP request returned an unsuccessful status code
except requests.RequestException as e:
    raise SystemExit(f"Failed to make the request. Error: {e}")

# Handle the response as needed (e.g., print or process)
result = response.json()

# Assuming your JSON response is stored in a variable named `response_json`
response_json = result
# Accessing specific values
choices = response_json['choices']
message_content = choices[0]['message']['content']

# Print the content of the message
print(message_content)
# Out:
# StatementMeta(, 94457e5a-46ec-41d8-af4e-c0c36c998a89, 3, Finished, Available, Finished)
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[8], line 54
#      53     response = requests.post(GPT4V_ENDPOINT, headers=headers, json=payload)
# ---> 54     response.raise_for_status()  # Will raise an HTTPError if the HTTP request returned an unsuccessful status code
#      55 except requests.RequestException as e:
#
# File ~/cluster-env/trident_env/lib/python3.11/site-packages/requests/models.py:1021, in Response.raise_for_status(self)
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: DeploymentNotFound for url: https://firstazureopenai05022024.openai.azure.com/openai/deployments/gpt-40/chat/completions?api-version=2024-02-15-preview
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[8], line 56
#      55 except requests.RequestException as e:
# ---> 56     raise SystemExit(f"Failed to make the request. Error: {e}")
#      58 # Handle the response as needed (e.g., print or process)
#
# SystemExit: Failed to make the request. Error: 404 Client Error: DeploymentNotFound for url: https://firstazureopenai05022024.openai.azure.com/openai/deployments/gpt-40/chat/completions?api-version=2024-02-15-preview
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File ~/cluster-env/trident_env/lib/python3.11/site-packages/IPython/core/interactiveshell.py:2121, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2118 if exception_only:
#    2119     stb = ['An exception has occurred, use %tb to see '
#    2120            'the full traceback.\n']
# -> 2121     stb.extend(self.InteractiveTB.get_exception_only(etype,
#    2122                                                      value))
#    2123 else:
#    2125     def contains_exceptiongroup(val):
#
# File ~/cluster-env/trident_env/lib/python3.11/site-packages/IPython/core/ultratb.py:710, in ListTB.get_exception_only(self, etype, value)
#     702 def get_exception_only(self, etype, value):
#     703     """Only print the exception type and message, without a traceback.
#     704
#     705     Parameters
#    (...)
#     708     value : exception value
#     709     """
# --> 710     return ListTB.structured_traceback(self, etype, value)
#
# File ~/cluster-env/trident_env/lib/python3.11/site-packages/IPython/core/ultratb.py:568, in ListTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     565     chained_exc_ids.add(id(exception[1]))
#     566     chained_exceptions_tb_offset = 0
#     567     out_list = (
# --> 568         self.structured_traceback(
#     569             etype,
#     570             evalue,
#     571             (etb, chained_exc_ids),  # type: ignore
#     572             chained_exceptions_tb_offset,
#     573             context,
#     574         )
#     575         + chained_exception_message
#     576         + out_list)
#     578 return out_list
#
# File ~/cluster-env/trident_env/lib/python3.11/site-packages/IPython/core/ultratb.py:1435, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1433 else:
#    1434     self.tb = etb
# -> 1435 return FormattedTB.structured_traceback(
#    1436     self, etype, evalue, etb, tb_offset, number_of_lines_of_context
#    1437 )
#
# File ~/cluster-env/trident_env/lib/python3.11/site-packages/IPython/core/ultratb.py:1326, in FormattedTB.structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1323 mode = self.mode
#    1324 if mode in self.verbose_modes:
#    1325     # Verbose modes need a full traceback
# -> 1326     return VerboseTB.structured_traceback(
#    1327         self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1328     )
#    1329 elif mode == 'Minimal':
#    1330     return ListTB.get_exception_only(self, etype, value)
#
# File ~/cluster-env/trident_env/lib/python3.11/site-packages/IPython/core/ultratb.py:1173, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1164 def structured_traceback(
#    1165     self,
#    1166     etype: type,
#    (...)
#    1170     number_of_lines_of_context: int = 5,
#    1171 ):
#    1172     """Return a nice text document describing the traceback."""
# -> 1173     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1174                                                            tb_offset)
#    1176     colors = self.Colors  # just a shorthand + quicker name lookup
#    1177     colorsnormal = colors.Normal  # used a lot
#
# File ~/cluster-env/trident_env/lib/python3.11/site-packages/IPython/core/ultratb.py:1063, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1060 assert isinstance(tb_offset, int)
#    1061 head = self.prepare_header(str(etype), self.long_header)
#    1062 records = (
# -> 1063     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#    1064 )
#    1066 frames = []
#    1067 skipped = 0
#
# File ~/cluster-env/trident_env/lib/python3.11/site-packages/IPython/core/ultratb.py:1131, in VerboseTB.get_records(self, etb, number_of_lines_of_context, tb_offset)
#    1129 while cf is not None:
#    1130     try:
# -> 1131         mod = inspect.getmodule(cf.tb_frame)
#    1132         if mod is not None:
#    1133             mod_name = mod.__name__
#
# AttributeError: 'tuple' object has no attribute 'tb_frame'

# %% [markdown]
# **Example 2:** A diagram explaining the process RAG process

# %%
import os
import requests
import base64
import json


# Configuration
GPT4V_KEY = "55457392c21046e8bf4223a6dac91316"
IMAGE_PATH = "/lakehouse/default/Files/vector database.png"
encoded_image = base64.b64encode(open(IMAGE_PATH, 'rb').read()).decode('ascii')
headers = {
    "Content-Type": "application/json",
    "api-key": GPT4V_KEY,
}

# Payload for the request
payload = {
  "messages": [
    {
      "role": "system",
      "content": [
        {
          "type": "text",
          "text": "You are an AI assistant that helps people find information."
        }
      ]
    },
    {
      "role": "user",
      "content": [
        {
          "type": "text",
          "text": "hi"
        }
      ]
    },
    {
      "role": "assistant",
      "content": [
        {
          "type": "text",
          "text": "Hello! How can I assist you today?"
        }
      ]
    },
    {
      "role": "user",
      "content": [
        {
          "type": "image_url",
          "image_url": {
            "url": f"data:image/jpeg;base64,{encoded_image}"
          }
        },
        {
          "type": "text",
          "text": "can you please explin the image?"
        }
      ]
    }
  ],
  "temperature": 0.7,
  "top_p": 0.95,
  "max_tokens": 800
}

GPT4V_ENDPOINT = "https://firstazureopenai05022024.openai.azure.com/openai/deployments/gpt-40/chat/completions?api-version=2024-02-15-preview"

# Send request
try:
    response = requests.post(GPT4V_ENDPOINT, headers=headers, json=payload)
    response.raise_for_status()  # Will raise an HTTPError if the HTTP request returned an unsuccessful status code
except requests.RequestException as e:
    raise SystemExit(f"Failed to make the request. Error: {e}")

# Handle the response as needed (e.g., print or process)
result = response.json()

# Assuming your JSON response is stored in a variable named `response_json`
response_json = result
# Accessing specific values
choices = response_json['choices']
message_content = choices[0]['message']['content']

# Print the content of the message
print(message_content)
# Out:
# StatementMeta(, 94457e5a-46ec-41d8-af4e-c0c36c998a89, 4, Finished, Available, Finished)
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[11], line 72
#      71     response = requests.post(GPT4V_ENDPOINT, headers=headers, json=payload)
# ---> 72     response.raise_for_status()  # Will raise an HTTPError if the HTTP request returned an unsuccessful status code
#      73 except requests.RequestException as e:
#
# File ~/cluster-env/trident_env/lib/python3.11/site-packages/requests/models.py:1021, in Response.raise_for_status(self)
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: DeploymentNotFound for url: https://firstazureopenai05022024.openai.azure.com/openai/deployments/gpt-40/chat/completions?api-version=2024-02-15-preview
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[11], line 74
#      73 except requests.RequestException as e:
# ---> 74     raise SystemExit(f"Failed to make the request. Error: {e}")
#      76 # Handle the response as needed (e.g., print or process)
#
# SystemExit: Failed to make the request. Error: 404 Client Error: DeploymentNotFound for url: https://firstazureopenai05022024.openai.azure.com/openai/deployments/gpt-40/chat/completions?api-version=2024-02-15-preview
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File ~/cluster-env/trident_env/lib/python3.11/site-packages/IPython/core/interactiveshell.py:2121, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2118 if exception_only:
#    2119     stb = ['An exception has occurred, use %tb to see '
#    2120            'the full traceback.\n']
# -> 2121     stb.extend(self.InteractiveTB.get_exception_only(etype,
#    2122                                                      value))
#    2123 else:
#    2125     def contains_exceptiongroup(val):
#
# File ~/cluster-env/trident_env/lib/python3.11/site-packages/IPython/core/ultratb.py:710, in ListTB.get_exception_only(self, etype, value)
#     702 def get_exception_only(self, etype, value):
#     703     """Only print the exception type and message, without a traceback.
#     704
#     705     Parameters
#    (...)
#     708     value : exception value
#     709     """
# --> 710     return ListTB.structured_traceback(self, etype, value)
#
# File ~/cluster-env/trident_env/lib/python3.11/site-packages/IPython/core/ultratb.py:568, in ListTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     565     chained_exc_ids.add(id(exception[1]))
#     566     chained_exceptions_tb_offset = 0
#     567     out_list = (
# --> 568         self.structured_traceback(
#     569             etype,
#     570             evalue,
#     571             (etb, chained_exc_ids),  # type: ignore
#     572             chained_exceptions_tb_offset,
#     573             context,
#     574         )
#     575         + chained_exception_message
#     576         + out_list)
#     578 return out_list
#
# File ~/cluster-env/trident_env/lib/python3.11/site-packages/IPython/core/ultratb.py:1435, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1433 else:
#    1434     self.tb = etb
# -> 1435 return FormattedTB.structured_traceback(
#    1436     self, etype, evalue, etb, tb_offset, number_of_lines_of_context
#    1437 )
#
# File ~/cluster-env/trident_env/lib/python3.11/site-packages/IPython/core/ultratb.py:1326, in FormattedTB.structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1323 mode = self.mode
#    1324 if mode in self.verbose_modes:
#    1325     # Verbose modes need a full traceback
# -> 1326     return VerboseTB.structured_traceback(
#    1327         self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1328     )
#    1329 elif mode == 'Minimal':
#    1330     return ListTB.get_exception_only(self, etype, value)
#
# File ~/cluster-env/trident_env/lib/python3.11/site-packages/IPython/core/ultratb.py:1173, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1164 def structured_traceback(
#    1165     self,
#    1166     etype: type,
#    (...)
#    1170     number_of_lines_of_context: int = 5,
#    1171 ):
#    1172     """Return a nice text document describing the traceback."""
# -> 1173     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1174                                                            tb_offset)
#    1176     colors = self.Colors  # just a shorthand + quicker name lookup
#    1177     colorsnormal = colors.Normal  # used a lot
#
# File ~/cluster-env/trident_env/lib/python3.11/site-packages/IPython/core/ultratb.py:1063, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1060 assert isinstance(tb_offset, int)
#    1061 head = self.prepare_header(str(etype), self.long_header)
#    1062 records = (
# -> 1063     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#    1064 )
#    1066 frames = []
#    1067 skipped = 0
#
# File ~/cluster-env/trident_env/lib/python3.11/site-packages/IPython/core/ultratb.py:1131, in VerboseTB.get_records(self, etb, number_of_lines_of_context, tb_offset)
#    1129 while cf is not None:
#    1130     try:
# -> 1131         mod = inspect.getmodule(cf.tb_frame)
#    1132         if mod is not None:
#    1133             mod_name = mod.__name__
#
# AttributeError: 'tuple' object has no attribute 'tb_frame'

# %% [markdown]
# **Example 3:** The image has barcode details. It has rules to generate driving license in the UK
#
# Using GPT 40, we will get real time performance by doing decode image, you can schedule further process base on result of decode.
#
# Here are some practical use cases for using GPT-4.0 to decode and encode barcodes, specifically for UK Driving Licence numbers:
#
#
# **Use Case 1: Verification System at Traffic Stops**
# **Scenario:** Police officers need to quickly verify the authenticity and details of a driver's licence during traffic stops.
#
# **Use Case 2: Automated Check-in at Car Rentals**
#
# **Scenario:** Car rental services want to streamline the check-in process by quickly verifying customer driving licences
#
# **Process:**
# 1.	Customer Scans Licence: At the rental kiosk, the customer scans their driving licence barcode.
# 2.	Decode Information: The kiosk system uses GPT-4.0 to decode the barcode and extract the necessary information.
# 3.	Pre-fill Forms: The extracted information (name, date of birth, licence number) is used to pre-fill rental agreement forms.
# 4.	Quick Approval: The system checks the licence details in real-time against a database for any restrictions or issues, enabling quick approval.
#
# **Use Case 3: Online Identity Verification**
#
# **Scenario:** An online service (e.g., financial institution, insurance company) needs to verify a user's identity based on their driving licence.
#
# Process:
# 1.	**User Uploads Licence: **The user uploads a photo of their driving licence.
# 2.	**Extract Barcode Data:** The system extracts the barcode from the uploaded image.
# 3.	**Decode with GPT-4.0:** The extracted barcode data is sent to GPT-4.0, which decodes it to retrieve the user’s details.
# 4.	**Verify Identity:** The system compares the decoded details with the user’s provided information to verify identity.
# 5.	**Secure Processing:** The decoded information is securely processed and stored according to data protection regulations.

# %%
import os
import requests
import base64
import json


# Configuration
GPT4V_KEY = "55457392c21046e8bf4223a6dac91316"
IMAGE_PATH = "/lakehouse/default/Files/Driving Licence encoding rules.png"
encoded_image = base64.b64encode(open(IMAGE_PATH, 'rb').read()).decode('ascii')
headers = {
    "Content-Type": "application/json",
    "api-key": GPT4V_KEY,
}

# Payload for the request
payload = {
  "messages": [
    {
      "role": "system",
      "content": [
        {
          "type": "text",
          "text": "You are an AI assistant that helps people find information."
        }
      ]
    },
    {
      "role": "user",
      "content": [
        {
          "type": "image_url",
          "image_url": {
            "url": f"data:image/jpeg;base64,{encoded_image}"
          }
        },
        {
          "type": "text",
          "text": "can you please explin the image? Can you please generate SP to decode Driving licence number?"
        }
      ]
    }
  ],
  "temperature": 0.7,
  "top_p": 0.95,
  "max_tokens": 800
}

GPT4V_ENDPOINT = "https://firstazureopenai05022024.openai.azure.com/openai/deployments/gpt-40/chat/completions?api-version=2024-02-15-preview"

# Send request
try:
    response = requests.post(GPT4V_ENDPOINT, headers=headers, json=payload)
    response.raise_for_status()  # Will raise an HTTPError if the HTTP request returned an unsuccessful status code
except requests.RequestException as e:
    raise SystemExit(f"Failed to make the request. Error: {e}")

# Handle the response as needed (e.g., print or process)
result = response.json()

# Assuming your JSON response is stored in a variable named `response_json`
response_json = result
# Accessing specific values
choices = response_json['choices']
message_content = choices[0]['message']['content']

# Print the content of the message
print(message_content)
# Out:
# StatementMeta(, 94457e5a-46ec-41d8-af4e-c0c36c998a89, 5, Finished, Available, Finished)
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[14], line 54
#      53     response = requests.post(GPT4V_ENDPOINT, headers=headers, json=payload)
# ---> 54     response.raise_for_status()  # Will raise an HTTPError if the HTTP request returned an unsuccessful status code
#      55 except requests.RequestException as e:
#
# File ~/cluster-env/trident_env/lib/python3.11/site-packages/requests/models.py:1021, in Response.raise_for_status(self)
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: DeploymentNotFound for url: https://firstazureopenai05022024.openai.azure.com/openai/deployments/gpt-40/chat/completions?api-version=2024-02-15-preview
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[14], line 56
#      55 except requests.RequestException as e:
# ---> 56     raise SystemExit(f"Failed to make the request. Error: {e}")
#      58 # Handle the response as needed (e.g., print or process)
#
# SystemExit: Failed to make the request. Error: 404 Client Error: DeploymentNotFound for url: https://firstazureopenai05022024.openai.azure.com/openai/deployments/gpt-40/chat/completions?api-version=2024-02-15-preview
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File ~/cluster-env/trident_env/lib/python3.11/site-packages/IPython/core/interactiveshell.py:2121, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2118 if exception_only:
#    2119     stb = ['An exception has occurred, use %tb to see '
#    2120            'the full traceback.\n']
# -> 2121     stb.extend(self.InteractiveTB.get_exception_only(etype,
#    2122                                                      value))
#    2123 else:
#    2125     def contains_exceptiongroup(val):
#
# File ~/cluster-env/trident_env/lib/python3.11/site-packages/IPython/core/ultratb.py:710, in ListTB.get_exception_only(self, etype, value)
#     702 def get_exception_only(self, etype, value):
#     703     """Only print the exception type and message, without a traceback.
#     704
#     705     Parameters
#    (...)
#     708     value : exception value
#     709     """
# --> 710     return ListTB.structured_traceback(self, etype, value)
#
# File ~/cluster-env/trident_env/lib/python3.11/site-packages/IPython/core/ultratb.py:568, in ListTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     565     chained_exc_ids.add(id(exception[1]))
#     566     chained_exceptions_tb_offset = 0
#     567     out_list = (
# --> 568         self.structured_traceback(
#     569             etype,
#     570             evalue,
#     571             (etb, chained_exc_ids),  # type: ignore
#     572             chained_exceptions_tb_offset,
#     573             context,
#     574         )
#     575         + chained_exception_message
#     576         + out_list)
#     578 return out_list
#
# File ~/cluster-env/trident_env/lib/python3.11/site-packages/IPython/core/ultratb.py:1435, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1433 else:
#    1434     self.tb = etb
# -> 1435 return FormattedTB.structured_traceback(
#    1436     self, etype, evalue, etb, tb_offset, number_of_lines_of_context
#    1437 )
#
# File ~/cluster-env/trident_env/lib/python3.11/site-packages/IPython/core/ultratb.py:1326, in FormattedTB.structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1323 mode = self.mode
#    1324 if mode in self.verbose_modes:
#    1325     # Verbose modes need a full traceback
# -> 1326     return VerboseTB.structured_traceback(
#    1327         self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1328     )
#    1329 elif mode == 'Minimal':
#    1330     return ListTB.get_exception_only(self, etype, value)
#
# File ~/cluster-env/trident_env/lib/python3.11/site-packages/IPython/core/ultratb.py:1173, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1164 def structured_traceback(
#    1165     self,
#    1166     etype: type,
#    (...)
#    1170     number_of_lines_of_context: int = 5,
#    1171 ):
#    1172     """Return a nice text document describing the traceback."""
# -> 1173     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1174                                                            tb_offset)
#    1176     colors = self.Colors  # just a shorthand + quicker name lookup
#    1177     colorsnormal = colors.Normal  # used a lot
#
# File ~/cluster-env/trident_env/lib/python3.11/site-packages/IPython/core/ultratb.py:1063, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1060 assert isinstance(tb_offset, int)
#    1061 head = self.prepare_header(str(etype), self.long_header)
#    1062 records = (
# -> 1063     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#    1064 )
#    1066 frames = []
#    1067 skipped = 0
#
# File ~/cluster-env/trident_env/lib/python3.11/site-packages/IPython/core/ultratb.py:1131, in VerboseTB.get_records(self, etb, number_of_lines_of_context, tb_offset)
#    1129 while cf is not None:
#    1130     try:
# -> 1131         mod = inspect.getmodule(cf.tb_frame)
#    1132         if mod is not None:
#    1133             mod_name = mod.__name__
#
# AttributeError: 'tuple' object has no attribute 'tb_frame'

# %%
import os
import requests
import base64
import json


# Configuration
GPT4V_KEY = "55457392c21046e8bf4223a6dac91316"
IMAGE_PATH = "/lakehouse/default/Files/Driving Licence encoding rules.png"
encoded_image = base64.b64encode(open(IMAGE_PATH, 'rb').read()).decode('ascii')
headers = {
    "Content-Type": "application/json",
    "api-key": GPT4V_KEY,
}

# Payload for the request
payload = {
  "messages": [
    {
      "role": "system",
      "content": [
        {
          "type": "text",
          "text": "You are an AI assistant that helps people find information."
        }
      ]
    },
    {
      "role": "user",
      "content": [
        {
          "type": "image_url",
          "image_url": {
            "url": f"data:image/jpeg;base64,{encoded_image}"
          }
        },
        {
          "type": "text",
          "text": "Can you please generate Azure SQL Storeprocedure to decode Driving licence number?And Create 5 sample data to test"
        }
      ]
    }
  ],
  "temperature": 0.7,
  "top_p": 0.95,
  "max_tokens": 800
}

GPT4V_ENDPOINT = "https://firstazureopenai05022024.openai.azure.com/openai/deployments/gpt-40/chat/completions?api-version=2024-02-15-preview"

# Send request
try:
    response = requests.post(GPT4V_ENDPOINT, headers=headers, json=payload)
    response.raise_for_status()  # Will raise an HTTPError if the HTTP request returned an unsuccessful status code
except requests.RequestException as e:
    raise SystemExit(f"Failed to make the request. Error: {e}")

# Handle the response as needed (e.g., print or process)
result = response.json()

# Assuming your JSON response is stored in a variable named `response_json`
response_json = result
# Accessing specific values
choices = response_json['choices']
message_content = choices[0]['message']['content']

# Print the content of the message
print(message_content)
# Out:
# StatementMeta(, 94457e5a-46ec-41d8-af4e-c0c36c998a89, 6, Finished, Available, Finished)
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[17], line 54
#      53     response = requests.post(GPT4V_ENDPOINT, headers=headers, json=payload)
# ---> 54     response.raise_for_status()  # Will raise an HTTPError if the HTTP request returned an unsuccessful status code
#      55 except requests.RequestException as e:
#
# File ~/cluster-env/trident_env/lib/python3.11/site-packages/requests/models.py:1021, in Response.raise_for_status(self)
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: DeploymentNotFound for url: https://firstazureopenai05022024.openai.azure.com/openai/deployments/gpt-40/chat/completions?api-version=2024-02-15-preview
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[17], line 56
#      55 except requests.RequestException as e:
# ---> 56     raise SystemExit(f"Failed to make the request. Error: {e}")
#      58 # Handle the response as needed (e.g., print or process)
#
# SystemExit: Failed to make the request. Error: 404 Client Error: DeploymentNotFound for url: https://firstazureopenai05022024.openai.azure.com/openai/deployments/gpt-40/chat/completions?api-version=2024-02-15-preview
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File ~/cluster-env/trident_env/lib/python3.11/site-packages/IPython/core/interactiveshell.py:2121, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2118 if exception_only:
#    2119     stb = ['An exception has occurred, use %tb to see '
#    2120            'the full traceback.\n']
# -> 2121     stb.extend(self.InteractiveTB.get_exception_only(etype,
#    2122                                                      value))
#    2123 else:
#    2125     def contains_exceptiongroup(val):
#
# File ~/cluster-env/trident_env/lib/python3.11/site-packages/IPython/core/ultratb.py:710, in ListTB.get_exception_only(self, etype, value)
#     702 def get_exception_only(self, etype, value):
#     703     """Only print the exception type and message, without a traceback.
#     704
#     705     Parameters
#    (...)
#     708     value : exception value
#     709     """
# --> 710     return ListTB.structured_traceback(self, etype, value)
#
# File ~/cluster-env/trident_env/lib/python3.11/site-packages/IPython/core/ultratb.py:568, in ListTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     565     chained_exc_ids.add(id(exception[1]))
#     566     chained_exceptions_tb_offset = 0
#     567     out_list = (
# --> 568         self.structured_traceback(
#     569             etype,
#     570             evalue,
#     571             (etb, chained_exc_ids),  # type: ignore
#     572             chained_exceptions_tb_offset,
#     573             context,
#     574         )
#     575         + chained_exception_message
#     576         + out_list)
#     578 return out_list
#
# File ~/cluster-env/trident_env/lib/python3.11/site-packages/IPython/core/ultratb.py:1435, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1433 else:
#    1434     self.tb = etb
# -> 1435 return FormattedTB.structured_traceback(
#    1436     self, etype, evalue, etb, tb_offset, number_of_lines_of_context
#    1437 )
#
# File ~/cluster-env/trident_env/lib/python3.11/site-packages/IPython/core/ultratb.py:1326, in FormattedTB.structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1323 mode = self.mode
#    1324 if mode in self.verbose_modes:
#    1325     # Verbose modes need a full traceback
# -> 1326     return VerboseTB.structured_traceback(
#    1327         self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1328     )
#    1329 elif mode == 'Minimal':
#    1330     return ListTB.get_exception_only(self, etype, value)
#
# File ~/cluster-env/trident_env/lib/python3.11/site-packages/IPython/core/ultratb.py:1173, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1164 def structured_traceback(
#    1165     self,
#    1166     etype: type,
#    (...)
#    1170     number_of_lines_of_context: int = 5,
#    1171 ):
#    1172     """Return a nice text document describing the traceback."""
# -> 1173     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1174                                                            tb_offset)
#    1176     colors = self.Colors  # just a shorthand + quicker name lookup
#    1177     colorsnormal = colors.Normal  # used a lot
#
# File ~/cluster-env/trident_env/lib/python3.11/site-packages/IPython/core/ultratb.py:1063, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1060 assert isinstance(tb_offset, int)
#    1061 head = self.prepare_header(str(etype), self.long_header)
#    1062 records = (
# -> 1063     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#    1064 )
#    1066 frames = []
#    1067 skipped = 0
#
# File ~/cluster-env/trident_env/lib/python3.11/site-packages/IPython/core/ultratb.py:1131, in VerboseTB.get_records(self, etb, number_of_lines_of_context, tb_offset)
#    1129 while cf is not None:
#    1130     try:
# -> 1131         mod = inspect.getmodule(cf.tb_frame)
#    1132         if mod is not None:
#    1133             mod_name = mod.__name__
#
# AttributeError: 'tuple' object has no attribute 'tb_frame'
