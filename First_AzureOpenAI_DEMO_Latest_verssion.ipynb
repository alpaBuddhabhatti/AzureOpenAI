# %%
#Note: The openai-python library support for Azure OpenAI is in preview.
      #Note: This code sample requires OpenAI Python library version 1.0.0 or higher.
import os
from openai import AzureOpenAI


client = AzureOpenAI(
  azure_endpoint = "https://yourAzureOpenAI.openai.azure.com/", 
  api_key="YourAzureOpenAIKey", #os.getenv("AZURE_OPENAI_KEY"),  
  api_version="2024-02-15-preview"
)


message_text = [{"role":"system","content":"You are an AI assistant that helps people find information."}]

completion = client.chat.completions.create(
  model="gpt-35-turbo", # model = "deployment_name"
  messages = message_text,
  temperature=0.7,
  max_tokens=800,
  top_p=0.95,
  frequency_penalty=0,
  presence_penalty=0,
  stop=None
)
# Out:
# StatementMeta(, 2d28b982-addd-4997-93cd-d9d9ef1d4181, 4, Finished, Available)
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 4
#       1 #Note: The openai-python library support for Azure OpenAI is in preview.
#       2       #Note: This code sample requires OpenAI Python library version 1.0.0 or higher.
#       3 import os
# ----> 4 from openai import AzureOpenAI
#       7 client = AzureOpenAI(
#       8   azure_endpoint = "https://firstazureopenai05022024.openai.azure.com/",
#       9   api_key="55457392c21046e8bf4223a6dac91316", #os.getenv("AZURE_OPENAI_KEY"),
#      10   api_version="2024-02-15-preview"
#      11 )
#      14 message_text = [{"role":"system","content":"You are an AI assistant that helps people find information."}]
#
# ImportError: cannot import name 'AzureOpenAI' from 'openai' (/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/openai/__init__.py)

# %%
# %pip install openai --upgrade 
# !pip install --upgrade pip
# Out:
# StatementMeta(, 2d28b982-addd-4997-93cd-d9d9ef1d4181, 10, Finished, Available)
# Requirement already satisfied: openai in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (0.27.8)
# Collecting openai
#   Downloading openai-1.14.3-py3-none-any.whl (262 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.9/262.9 kB 16.2 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from openai) (3.7.1)
# Collecting distro<2,>=1.7.0 (from openai)
#   Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 37.2 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3,>=1.9.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from openai) (1.10.9)
# Requirement already satisfied: sniffio in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from openai) (4.66.1)
# Collecting typing-extensions<5,>=4.7 (from openai)
#   Downloading typing_extensions-4.10.0-py3-none-any.whl (33 kB)
# Requirement already satisfied: idna>=2.8 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (3.4)
# Requirement already satisfied: exceptiongroup in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (1.1.3)
# Requirement already satisfied: certifi in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (2023.7.22)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 39.9 MB/s eta 0:00:00
# Requirement already satisfied: h11<0.15,>=0.13 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Installing collected packages: typing-extensions, httpcore, distro, httpx, openai
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.5.0
#     Not uninstalling typing-extensions at /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages, outside environment /nfs4/pyenv-3cce7fdb-6b76-423e-9900-d7030eb1cdb8
#     Can't uninstall 'typing_extensions'. No files were found to uninstall.
#   Attempting uninstall: openai
#     Found existing installation: openai 0.27.8
#     Not uninstalling openai at /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages, outside environment /nfs4/pyenv-3cce7fdb-6b76-423e-9900-d7030eb1cdb8
#     Can't uninstall 'openai'. No files were found to uninstall.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sentence-transformers 2.0.0 requires sentencepiece, which is not installed.
# sentence-transformers 2.0.0 requires torchvision, which is not installed.
# dash 2.14.0 requires Flask<2.3.0,>=1.0.4, but you have flask 3.0.0 which is incompatible.
# dash 2.14.0 requires Werkzeug<2.3.0, but you have werkzeug 3.0.1 which is incompatible.
# tensorflow 2.12.1 requires typing-extensions<4.6.0,>=3.6.6, but you have typing-extensions 4.10.0 which is incompatible.
# Successfully installed distro-1.9.0 httpcore-1.0.5 httpx-0.27.0 openai-1.14.3 typing-extensions-4.10.0
#
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pip in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (23.1.2)
# Collecting pip
#   Using cached pip-24.0-py3-none-any.whl (2.1 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 23.1.2
#     Uninstalling pip-23.1.2:
#       Successfully uninstalled pip-23.1.2
# Successfully installed pip-24.0
# Warning: PySpark kernel has been restarted to use updated packages.

# %%
import openai
# Out:
# StatementMeta(, 2d28b982-addd-4997-93cd-d9d9ef1d4181, 12, Finished, Available)

# %%
print(openai.VERSION)
# Out:
# StatementMeta(, 2d28b982-addd-4997-93cd-d9d9ef1d4181, 13, Finished, Available)
# 1.14.3

# %%
#Note: The openai-python library support for Azure OpenAI is in preview.
      #Note: This code sample requires OpenAI Python library version 1.0.0 or higher.
import os
from openai import AzureOpenAI


client = AzureOpenAI(
  azure_endpoint = "https://yourAzureOpenAI.openai.azure.com/", 
  api_key="YourAzureOpenAIKey", #os.getenv("AZURE_OPENAI_KEY"),  
  api_version="2024-02-15-preview"
)



message_text = [{"role":"system","content":"You are an AI assistant that helps people find information."}]

completion = client.chat.completions.create(
  model="gpt-35-turbo", # model = "deployment_name"
  messages = message_text,
  temperature=0.7,
  max_tokens=800,
  top_p=0.95,
  frequency_penalty=0,
  presence_penalty=0,
  stop=None
)
# Out:
# StatementMeta(, 2d28b982-addd-4997-93cd-d9d9ef1d4181, 14, Finished, Available)

# %%
print(completion.choices[0].message.content)
# Out:
# StatementMeta(, 2d28b982-addd-4997-93cd-d9d9ef1d4181, 15, Finished, Available)
# Hello! How can I assist you today?
